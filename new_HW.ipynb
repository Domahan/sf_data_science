# %%
import pandas as pd

melb_data = pd.read_csv('data/melb_data.csv', sep=',')

melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
melb_data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
# Задание 1

melb_data.iloc[15]['Price']
# Out:
# 1310000.0

# %%
#Задание 2

melb_data.iloc[90]['Date']
# Out:
# '10/09/2016'

# %%
#Задание 3

S1=melb_data.iloc[3521]['Landsize']
S2=melb_data.iloc[1690]['Landsize']
S1/S2
# Out:
# 2.7857142857142856

# %%
# Задание 6.5
melb_data.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# ...

# %%
melb_data['CouncilArea'].value_counts()
# Out:
# CouncilArea
# Moreland             1163
# Boroondara           1160
# Moonee Valley         997
# Darebin               934
# Glen Eira             848
# Stonnington           719
# Maribyrnong           692
# Yarra                 647
# Port Phillip          628
# Banyule               594
# Bayside               489
# Melbourne             470
# Hobsons Bay           434
# Brimbank              424
# Monash                333
# Manningham            311
# Whitehorse            304
# Kingston              207
# Whittlesea            167
# Hume                  164
# Wyndham                86
# Knox                   80
# Maroondah              80
# Melton                 66
# Frankston              53
# Greater Dandenong      52
# Casey                  38
# Nillumbik              36
# Yarra Ranges           18
# Cardinia                8
# Macedon Ranges          7
# Unavailable             1
# Moorabool               1
# Name: count, dtype: int64

# %%
melb_data.describe(include=['object'])
# Out:
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname         Coordinates
# count        12211                  13580               13580
# unique          33                      8               13097
# top       Moreland  Southern Metropolitan  -37.8361, 144.9966
# freq          1163                   4695                  12

# %%
melb_data['Type'].value_counts(normalize=True)
# Out:
# Type
# h    0.695803
# u    0.222165
# t    0.082032
# Name: proportion, dtype: float64

# %%
melb_data[melb_data['Bathroom'] == 0]
# Out:
#        index           Suburb            Address  Rooms Type      Price  \
# 139      139       Alphington        6 Naroon Rd      3    h  1485000.0
# 281      281         Armadale    3/50 Denbigh Rd      2    u   546000.0
# 505      505        Balaclava     5/11 Albion St      2    u   497500.0
# 584      584           Balwyn     5 Shrimpton Ct      2    h  1010000.0
# 913      913   Bentleigh East    579 Warrigal Rd      3    h   700000.0
# 1063    1063         Brighton          17 New St      3    h  1900000.0
# 1070    1070         Brighton        1/5 Webb St      3    t  1067000.0
# 1593    1593       Camberwell   5 Nicholsdale Rd      4    h  1400000.0
# 2253    2253      Elsternwick    5/29 Nepean Hwy      2    u   410000.0
# 2777    2777        Glen Iris         25 Hope St      2    h   845000.0
# 2797    2797        Glen Iris        130 High St      4    h  1550000.0
# 2808    2808        Glen Iris    1/64 Edgar St N      2    u   545000.0
# ...

# %%
melb_data[melb_data['Bathroom'] == 0].shape[0]
# Out:
# 34

# %%
melb_data[(melb_data['SellerG'] == 'Nelson')&(melb_data['Price']>3000000)]
# Out:
#        index         Suburb            Address  Rooms Type      Price Method  \
# 2553    2553        Fitzroy         17 Bell St      4    h  4011000.0      S
# 2579    2579  Fitzroy North    79 Delbridge St      4    h  3400000.0      S
# 6734    6734     Aberfeldie  126 The Boulevard      4    h  3900000.0      S
# 7695    7695  Carlton North       235 Amess St      4    h  3450000.0      S
# 11023  11023        Fitzroy   122 Nicholson St      4    h  3200000.0     VB
#
#       SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 2553   Nelson  27/11/2016       1.6  ...  2.0     286.0         275.0
# 2579   Nelson  14/05/2016       3.5  ...  1.0     445.0         175.0
# 6734   Nelson  10/12/2016       9.1  ...  4.0     670.0         375.0
# 7695   Nelson  13/05/2017       3.2  ...  1.0     515.0         203.0
# 11023  Nelson  12/08/2017       2.1  ...  0.0     225.0         126.0
#
#        YearBuilt    CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %%
melb_data[melb_data['BuildingArea'] == 0].describe()
# Out:
#               index      Rooms         Price   Distance     Postcode  \
# count     17.000000  17.000000  1.700000e+01  17.000000    17.000000
# mean   12598.705882   3.529412  1.448853e+06  11.611765  3118.470588
# std     2179.328129   0.874475  9.093566e+05   6.753414    51.576542
# min     4344.000000   2.000000  4.125000e+05   2.300000  3051.000000
# 25%    12412.000000   3.000000  8.140000e+05   7.000000  3076.000000
# 50%    13370.000000   3.000000  1.205000e+06  10.300000  3104.000000
# 75%    13434.000000   4.000000  1.950000e+06  14.300000  3166.000000
# max    13521.000000   5.000000  3.450000e+06  26.000000  3207.000000
#
#          Bedroom   Bathroom        Car     Landsize  BuildingArea  \
# count  17.000000  17.000000  17.000000    17.000000          17.0
# mean    3.529412   1.823529   1.823529   517.941176           0.0
# std     0.874475   0.635934   0.727607   288.063029           0.0
# min     2.000000   1.000000   1.000000   120.000000           0.0
# ...

# %%
#8.4
melb_data[((melb_data['Rooms'] >5) | (melb_data['YearBuilt'] > 2015)) & (melb_data['Price'] < 1000000)].describe()
# Out:
#               index      Rooms          Price   Distance     Postcode  \
# count     44.000000  44.000000      44.000000  44.000000    44.000000
# mean    7914.113636   4.386364  769238.636364  13.222727  3081.545455
# std     4007.231877   1.857930  164576.252513   7.770692    97.929603
# min       38.000000   2.000000  350000.000000   5.200000  3012.000000
# 25%     4880.500000   3.000000  666250.000000   8.125000  3018.750000
# 50%     8851.000000   4.000000  820000.000000  11.200000  3056.000000
# 75%    11043.750000   6.000000  903750.000000  16.375000  3081.500000
# max    13437.000000  10.000000  990000.000000  45.900000  3437.000000
#
#          Bedroom   Bathroom        Car     Landsize  BuildingArea  \
# count  44.000000  44.000000  44.000000    44.000000     44.000000
# mean    4.340909   2.386364   1.863636   507.340909    161.409091
# std     1.764550   0.654711   0.823800   302.453067     60.905691
# min     2.000000   1.000000   1.000000     0.000000     72.000000
# ...

# %%
melb_data[(melb_data['Type'] =='h') & (melb_data['Price'] < 3000000)].describe(include=['object'])
# Out:
#            Suburb     Address  Type Method SellerG        Date CouncilArea  \
# count        9220        9220  9220   9220    9220        9220        7999
# unique        313        9075     1      5     232          58          33
# top     Reservoir  2 Bruce St     h      S  Nelson  27/05/2017    Moreland
# freq          253           3  9220   6367    1154         334         842
#
#                    Regionname          Coordinates
# count                    9220                 9220
# unique                      8                 9160
# top     Northern Metropolitan  -37.74635, 144.9229
# freq                     2737                    2

# %%
#students
student_data = pd.read_csv('data/students_performance.csv', sep=',')
student_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#9.1
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
student_data.iloc[155]
# Out:
# gender                               female
# race/ethnicity                      group C
# parental level of education    some college
# lunch                              standard
# test preparation course           completed
# math score                               70
# reading score                            89
# writing score                            88
# Name: 155, dtype: object

# %%
student_data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
student_data.describe(include=['object'])
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %%
student_data.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test preparation course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %%
student_data.min()
# Out:
# gender                                     female
# race/ethnicity                            group A
# parental level of education    associate's degree
# lunch                                free/reduced
# test preparation course                 completed
# math score                                      0
# reading score                                  17
# writing score                                  10
# dtype: object

# %%
student_data.shape[0]
# Out:
# 1000

# %%
#9.8
round(student_data[student_data['test preparation course'] == 'completed']['reading score'].mean())
# Out:
# 74

# %%
#9.9
student_data[student_data['math score']==0].shape[0]
# Out:
# 1

# %%
#9.11
student_data["parental level of education"].value_counts(normalize=True)
# Out:
# parental level of education
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: proportion, dtype: float64

# %%
#9.10 
student_data[student_data['lunch'] == 'standard']['math score'].mean()
# Out:
# 70.03410852713178

# %%
student_data[student_data['lunch'] == 'free/reduced']['math score'].mean()
# Out:
# 58.92112676056338

# %%
#9.12
a = student_data[student_data['race/ethnicity'] == 'group A']['writing score'].median()
b = student_data[student_data['race/ethnicity'] == 'group C']['writing score'].mean()
print(round(abs(a - b)))
# Out:
# 6

# %%
#Modul 11
melb_df = melb_data.copy()
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
#Удалим столбцы index и Coordinates из таблицы с помощью метода drop(). Выведем первые пять строк таблицы и убедимся, что всё прошло успешно.
melb_df = melb_df.drop(['index', 'Coordinates'], axis=1)
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5      3067  ...       1.0  1.0     202.0         126.0
# 1  4/02/2016       2.5      3067  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5      3067  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5      3067  ...       2.0  1.0      94.0         126.0
# 4  4/06/2016       2.5      3067  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
#столбцы можно складывать, вычитать, умножать, делить между собой, а также возводить в степень
total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']
display(total_rooms)
# Out:
# 0         5.0
# 1         5.0
# 2         8.0
# 3         8.0
# 4         8.0
#          ...
# 13575    10.0
# 13576     8.0
# 13577     8.0
# 13578     9.0
# 13579     9.0
# Length: 13580, dtype: float64

# %%
#признак MeanRoomsArea, который соответствует средней площади одной комнаты для каждого объекта
melb_df['MeanRoomsArea'] = melb_df['BuildingArea'] / total_rooms
display(melb_df['MeanRoomsArea'])
# Out:
# 0        25.200000
# 1        15.800000
# 2        18.750000
# 3        15.750000
# 4        17.750000
#            ...
# 13575    12.600000
# 13576    16.625000
# 13577    15.750000
# 13578    17.444444
# 13579    12.444444
# Name: MeanRoomsArea, Length: 13580, dtype: float64

# %%
#AreaRatio, коэффициент соотношения площади здания (BuildingArea) и площади участка (Landsize)
diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area
display(melb_df['AreaRatio'])
# Out:
# 0       -0.231707
# 1       -0.327660
# 2        0.056338
# 3        0.145455
# 4        0.083969
#            ...
# 13575   -0.676093
# 13576   -0.429185
# 13577   -0.551601
# 13578   -0.693060
# 13579   -0.527426
# Name: AreaRatio, Length: 13580, dtype: float64

# %%
#2.4
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'area': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})
P=countries_df['population']*10**6/countries_df['area']
S=P.mean()
display(P)
display(S)
# Out:
# 0    421.976671
# 1      3.810842
# 2     32.796595
# 3      8.539467
# 4     75.377550
# 5     45.761079
# 6      6.253436
# dtype: float64
# 84.93080566562001

# %%
display(melb_df['Date'])
# Out:
# 0         3/12/2016
# 1         4/02/2016
# 2         4/03/2017
# 3         4/03/2017
# 4         4/06/2016
#             ...
# 13575    26/08/2017
# 13576    26/08/2017
# 13577    26/08/2017
# 13578    26/08/2017
# 13579    26/08/2017
# Name: Date, Length: 13580, dtype: object

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)
display(melb_df['Date'])
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
years_sold = melb_df['Date'].dt.year
print(years_sold)
print('Min year sold:', years_sold.min())
print('Max year sold:', years_sold.max())
print('Mode year sold:', years_sold.mode()[0])
# Out:
# 0        2016
# 1        2016
# 2        2017
# 3        2017
# 4        2016
#          ...
# 13575    2017
# 13576    2017
# 13577    2017
# 13578    2017
# 13579    2017
# Name: Date, Length: 13580, dtype: int32
# Min year sold: 2016
# Max year sold: 2017
# Mode year sold: 2017

# %%
#какие месяцы приходится пик продаж объектов недвижимости. Для этого выделим атрибут dt.month и на этот раз занесём результат в столбец MonthSale, а затем найдём относительную частоту продаж для каждого месяца от общего количества продаж — для этого используем метод value_counts() с параметром normalize (вывод в долях):

melb_df['MonthSale'] = melb_df['Date'].dt.month
melb_df['MonthSale'].value_counts(normalize=True)
# Out:
# MonthSale
# 5     0.149411
# 7     0.145950
# 9     0.135862
# 6     0.134757
# 8     0.114138
# 11    0.082032
# 4     0.069882
# 3     0.049926
# 12    0.044698
# 10    0.040574
# 2     0.032622
# 1     0.000147
# Name: proportion, dtype: float64

# %%
#вычислить, сколько дней прошло с 1 января 2016 года до момента продажи объекта.
delta_days = melb_df['Date'] - pd.to_datetime('2016-01-01') 
display(delta_days)
# Out:
# 0       337 days
# 1        34 days
# 2       428 days
# 3       428 days
# 4       155 days
#           ...
# 13575   603 days
# 13576   603 days
# 13577   603 days
# 13578   603 days
# 13579   603 days
# Name: Date, Length: 13580, dtype: timedelta64[ns]

# %%
# превратить количество дней из формата интервала в формат целого числа дней,
display(delta_days.dt.days)
# Out:
# 0        337
# 1         34
# 2        428
# 3        428
# 4        155
#         ...
# 13575    603
# 13576    603
# 13577    603
# 13578    603
# 13579    603
# Name: Date, Length: 13580, dtype: int64

# %%
#создадим признак возраста объекта недвижимости в годах на момент продажи. Для этого выделим из столбца с датой продажи год и вычтем из него год постройки здания. Результат оформим в виде столбца AgeBuilding:

melb_df['AgeBuilding'] = melb_df['Date'].dt.year - melb_df['YearBuilt']
display(melb_df['AgeBuilding'])
# Out:
# 0         46.0
# 1        116.0
# 2        117.0
# 3         47.0
# 4          2.0
#          ...
# 13575     36.0
# 13576     22.0
# 13577     20.0
# 13578     97.0
# 13579     97.0
# Name: AgeBuilding, Length: 13580, dtype: float64

# %%
#сколько объектов недвижимости было продано в выходные (суббота и воскресенье)

melb_df['WeekdaySale'] = melb_df['Date'].dt.dayofweek
weekend_count = melb_df[(melb_df['WeekdaySale'] == 5) | (melb_df['WeekdaySale'] == 6)].shape[0]
print(weekend_count)
# Out:
# 12822

# %%
ufo = pd.read_csv('data/ufo.csv', sep=',')

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City             18215 non-null  object
#  1   Colors Reported  2882 non-null   object
#  2   Shape Reported   15597 non-null  object
#  3   State            18241 non-null  object
#  4   Time             18241 non-null  object
# dtypes: object(5)
# memory usage: 712.7+ KB

# %%
ufo['Time'] = pd.to_datetime(ufo['Time'])
display(ufo['Time'])
# Out:
# 0       1930-06-01 22:00:00
# 1       1930-06-30 20:00:00
# 2       1931-02-15 14:00:00
# 3       1931-06-01 13:00:00
# 4       1933-04-18 19:00:00
#                 ...
# 18236   2000-12-31 23:00:00
# 18237   2000-12-31 23:00:00
# 18238   2000-12-31 23:45:00
# 18239   2000-12-31 23:45:00
# 18240   2000-12-31 23:59:00
# Name: Time, Length: 18241, dtype: datetime64[ns]

# %%
ufo['Time'].mode()
# Out:
# 0   1999-11-16 19:00:00
# Name: Time, dtype: datetime64[ns]

# %%
#средний интервал времени (в днях) между двумя последовательными случаями наблюдения НЛО в штате Невада (NV)
ufo['Date'] = ufo['Time'].dt.date
print(ufo[ufo['State']=='NV']['Date'].diff().dt.days.mean())
# Out:
# 68.92932862190813

# %%
#передадим функцию get_street_type в аргумент метода столбца apply().
street_types = melb_df['Address'].apply(get_street_type)
display(street_types)
# Out:
# 0        St
# 1        St
# 2        St
# 3        La
# 4        St
#          ..
# 13575    Cr
# 13576    Dr
# 13577    St
# 13578    St
# 13579    St
# Name: Address, Length: 13580, dtype: object

# %%
#сколько уникальных значений у нас получилось:
print(street_types.nunique())
# Out:
# 56

# %%
#посмотрим на частоту каждого подтипа улицы 
display(street_types.value_counts())
# Out:
# Address
# St           8012
# Rd           2825
# Ct            612
# Dr            447
# Av            321
# Gr            311
# Pde           211
# Pl            169
# Cr            152
# Cl            100
# La             67
# Bvd            53
# Tce            47
# Wy             40
# Avenue         40
# Cct            25
# Hwy            24
# Parade         15
# Boulevard      13
# Sq             11
# Crescent        9
# Cir             7
# Strand          7
# Esplanade       6
# Grove           5
# Gdns            4
# Grn             4
# Fairway         4
# Mews            4
# Crossway        3
# Righi           3
# Victoria        2
# Ridge           2
# Crofts          2
# Esp             2
# Glade           1
# Gra             1
# Ave             1
# Woodland        1
# Outlook         1
# Hts             1
# Highway         1
# Athol           1
# Summit          1
# Grand           1
# Res             1
# Nook            1
# Eyrie           1
# Dell            1
# ...

# %%
#Зададим n=10, т. е. мы хотим отобрать десять наиболее популярных подтипов. Извлечём их названия с помощью атрибута index, а результат занесём в переменную popular_stypes:

popular_stypes =street_types.value_counts().nlargest(10).index
print(popular_stypes)
# Out:
# Index(['St', 'Rd', 'Ct', 'Dr', 'Av', 'Gr', 'Pde', 'Pl', 'Cr', 'Cl'], dtype='object', name='Address')

# %%
#введём lambda-функцию, которая будет проверять, есть ли строка x в этом перечне, и, если это так, lambda-функция будет возвращать x, в противном случае она будет возвращать строку 'other'.
melb_df['StreetType'] = street_types.apply(lambda x: x if x in popular_stypes else 'other')
display(melb_df['StreetType'])
# Out:
# 0           St
# 1           St
# 2           St
# 3        other
# 4           St
#          ...
# 13575       Cr
# 13576       Dr
# 13577       St
# 13578       St
# 13579       St
# Name: StreetType, Length: 13580, dtype: object

# %%
print(melb_df['StreetType'].nunique())
# Out:
# 11

# %%
def get_weekend(weekday):
    if weekday == 5 or weekday == 6:
        return 1
    else: 
        return 0
melb_df['Weekend'] = melb_df['WeekdaySale'].apply(get_weekend)
print(round(melb_df[melb_df['Weekend']==1]['Price'].mean(), 2))
# Out:
# 1081198.64

# %%
#в столбце только 49 самых популярных компаний, а остальные обозначьте как 'other'
#во сколько раз минимальная цена объектов недвижимости, проданных компанией 'Nelson', больше минимальной цены объектов, проданных компаниями, обозначенными как 'other'
#Ответ округлите до десятых
popular_seller = melb_df['SellerG'].value_counts().nlargest(49).index
# заменяем имена компаний, не попавших в список популярных, на строку 'other'
melb_df['SellerG'] = melb_df['SellerG'].apply(lambda x: x if x in popular_seller else 'other') 

a = melb_df[melb_df['SellerG'] == 'Nelson']['Price'].min()
b = melb_df[melb_df['SellerG'] == 'other']['Price'].min()
print(round(a/b, 1))
# Out:
# 1.3

# %%
#определим число уникальных категорий в каждом столбце нашей таблицы melb_df
# создаём пустой список
unique_list = []
# пробегаемся по именам столбцов в таблице
for col in melb_df.columns:
    # создаём кортеж (имя столбца, число уникальных значений)
    item = (col, melb_df[col].nunique(),melb_df[col].dtypes)     # добавляем кортеж в список
    unique_list.append(item) 
# создаём вспомогательную таблицу и сортируем её
unique_counts = pd.DataFrame(
    unique_list,
    columns=['Column_Name', 'Num_Unique', 'Type']
).sort_values(by='Num_Unique',  ignore_index=True)
# выводим её на экран
display(unique_counts)
# Out:
#       Column_Name  Num_Unique            Type
# 0         Weekend           2           int64
# 1            Type           3          object
# 2     WeekdaySale           5           int32
# 3          Method           5          object
# 4      Regionname           8          object
# 5           Rooms           9           int64
# 6        Bathroom           9         float64
# 7             Car          11         float64
# 8      StreetType          11          object
# 9         Bedroom          12         float64
# 10      MonthSale          12           int32
# 11    CouncilArea          33          object
# 12        SellerG          50          object
# 13           Date          58  datetime64[ns]
# 14      YearBuilt         144         float64
# 15    AgeBuilding         152         float64
# 16       Postcode         198           int64
# 17       Distance         202         float64
# 18  Propertycount         311         float64
# ...

# %%
#выведем информацию о памяти, занимаемой текущей таблицей,
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom        13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13580 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
#Сделаем преобразование столбцов к типу данных category:
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in melb_df.columns: # цикл по именам столбцов
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_df[col] = melb_df[col].astype('category') # преобразуем тип столбца
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  category
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  category
#  6   SellerG        13580 non-null  category
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom        13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13580 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  category
#  16  CouncilArea    12211 non-null  category
# ...

# %%
# получить список уникальных категорий в столбце Regionname:
print(melb_df['Regionname'].cat.categories)
# Out:
# Index(['Eastern Metropolitan', 'Eastern Victoria', 'Northern Metropolitan',
#        'Northern Victoria', 'South-Eastern Metropolitan',
#        'Southern Metropolitan', 'Western Metropolitan', 'Western Victoria'],
#       dtype='object')

# %%
#каким образом столбец кодируется в виде чисел в памяти компьютера
display(melb_df['Regionname'].cat.codes)
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 13575    4
# 13576    6
# 13577    6
# 13578    6
# 13579    6
# Length: 13580, dtype: int8

# %%
#переименуем категории признака типа постройки Type — заменим их на полные названия ( u — unit, h — house, t — townhouse).
melb_df['Type'] = melb_df['Type'].cat.rename_categories({
    'u': 'unit',
    't': 'townhouse',
    'h': 'house'
})
display(melb_df['Type'])
# Out:
# 0        house
# 1        house
# 2        house
# 3        house
# 4        house
#          ...
# 13575    house
# 13576    house
# 13577    house
# 13578    house
# 13579    house
# Name: Type, Length: 13580, dtype: category
# Categories (3, object): ['house', 'townhouse', 'unit']

# %%
#обавить категорию flat в столбец Type с помощью метода акссесора cat add_categories()
melb_df['Type'] = melb_df['Type'].cat.add_categories('flat')
new_houses_types = pd.Series(['unit', 'house', 'flat', 'flat', 'house'])
new_houses_types = new_houses_types.astype(melb_df['Type'].dtype)
display(new_houses_types)
# Out:
# 0     unit
# 1    house
# 2     flat
# 3     flat
# 4    house
# dtype: category
# Categories (4, object): ['house', 'townhouse', 'unit', 'flat']

# %%
#5.2
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  category
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  category
#  6   SellerG        13580 non-null  category
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom        13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13580 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  category
#  16  CouncilArea    12211 non-null  category
# ...

# %%
#в столбце только 119 самых популярных пригородов, а остальные обозначьте как 'other'

popular_suburb = melb_df['Suburb'].value_counts().nlargest(119).index
# заменяем имена пригородов, не попавших в список популярных, на строку 'other'
melb_df['Suburb'] = melb_df['Suburb'].apply(lambda x: x if x in popular_suburb else 'other') 
melb_df['Suburb'] = melb_df['Suburb'].astype('category') # преобразуем тип столбца

print(melb_df['Suburb'].cat.categories)
# Out:
# Index(['Abbotsford', 'Aberfeldie', 'Airport West', 'Albert Park', 'Albion',
#        'Altona', 'Altona North', 'Armadale', 'Ascot Vale', 'Ashburton',
#        ...
#        'Thornbury', 'Toorak', 'Viewbank', 'Watsonia', 'Werribee',
#        'West Footscray', 'Williamstown', 'Windsor', 'Yarraville', 'other'],
#       dtype='object', length=119)

# %%
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  category
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  category
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  category
#  6   SellerG        13580 non-null  category
#  7   Date           13580 non-null  datetime64[ns]
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom        13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13580 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   13580 non-null  float64
#  15  YearBuilt      13580 non-null  category
#  16  CouncilArea    12211 non-null  category
# ...
